# %%
import pandas as pd
import re

# %%
# Load data
df = pd.read_csv('data.csv')

# %%
# Shows all columns
pd.set_option('display.max_columns', None)

# %%
# Changes 0 and 1 values to Yes and No
df['Are you self-employed?'] = df['Are you self-employed?'].replace({0: 'No', 1: 'Yes'})

# %%
# Shows unique values in a specific column
unique_values = df['Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?'].unique()
print(unique_values)
# Out:
# ["I don't know" 'Yes' nan 'No']

# %%
# Changes 0 and 1 values to Yes and No
df['Is your primary role within your company related to tech/IT?'] = df['Is your primary role within your company related to tech/IT?'].replace({0.: 'No', 1.: 'Yes'})

# %%
# Changes NaN values to Unknown
df['Do you know the options for mental health care available under your employer-provided coverage?'] = df['Do you know the options for mental health care available under your employer-provided coverage?'].fillna('Unknown')

# %%
# Changes NaN values to Unknown
df['Do you know the options for mental health care available under your employer-provided coverage?'] = df['Do you know the options for mental health care available under your employer-provided coverage?'].fillna('Unknown')

# %%
# Changes NaN values to Unknown
df['Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?'] = df['Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?'].fillna('Unknown')

# %%
# Changes 'Not eligible for coverage / N/A' to 'Not Eligible'
df['Does your employer provide mental health benefits as part of healthcare coverage?'] = df['Does your employer provide mental health benefits as part of healthcare coverage?'].replace('Not eligible for coverage / N/A', 'Not Eligible')

# %%
# Removes columns
df.drop('Does your employer provide mental health benefits as part of healthcare coverage?', axis=1, inplace=True)
df.drop('Do you know the options for mental health care available under your employer-provided coverage?', axis=1, inplace=True)
df.drop('Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?', axis=1, inplace=True)
df.drop('Do you think that discussing a physical health issue with your employer would have negative consequences?', axis=1, inplace=True)
df.drop('Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?', axis=1, inplace=True)
df.drop('If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?', axis=1, inplace=True)
df.drop('If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?', axis=1, inplace=True)
df.drop('If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?', axis=1, inplace=True)
df.drop('If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?', axis=1, inplace=True)
df.drop('Do you have previous employers?', axis=1, inplace=True)
df.drop('Have your previous employers provided mental health benefits?', axis=1, inplace=True)
df.drop('Were you aware of the options for mental health care provided by your previous employers?', axis=1, inplace=True)
df.drop('Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?', axis=1, inplace=True)
df.drop('Did your previous employers provide resources to learn more about mental health issues and how to seek help?', axis=1, inplace=True)
df.drop('Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?', axis=1, inplace=True)
df.drop('Do you think that discussing a mental health disorder with previous employers would have negative consequences?', axis=1, inplace=True)
df.drop('Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?', axis=1, inplace=True)
df.drop('Would you be willing to bring up a physical health issue with a potential employer in an interview?', axis=1, inplace=True)
df.drop('Why or why not?', axis=1, inplace=True)
df.drop('How willing would you be to share with friends and family that you have a mental illness?', axis=1, inplace=True)
df.drop('Do you have a family history of mental illness?', axis=1, inplace=True)
df.drop('Have you had a mental health disorder in the past?', axis=1, inplace=True)
df.drop('Do you currently have a mental health disorder?', axis=1, inplace=True)
df.drop('If yes, what condition(s) have you been diagnosed with?', axis=1, inplace=True)
df.drop('If maybe, what condition(s) do you believe you have?', axis=1, inplace=True)
df.drop('What country do you work in?', axis=1, inplace=True)
df.drop('What US state or territory do you work in?', axis=1, inplace=True)

# %%
# Removes column
df.drop('Do you think that discussing a physical health issue with previous employers would have negative consequences?', axis=1, inplace=True)

# %%
# Renames columns
df.columns = ['self_employed', 'company_size', 'tech_company', 'tech_role', 'mental_health_discussed', 
'mental_health_resources', 'leave_request_ease', 'negative_consequences', 'comfortable_coworkers', 
'comfortable_supervisor', 'mental_vs_physical_health', 'mental_health_coverage', 
'mental_health_resources_knowledge', 'productivity_affected', 'productivity_impact_pct', 
'discuss_past_coworkers', 'discuss_past_supervisor', 'past_employer_mental_health', 
'discuss_in_interview', 'interview_reason', 'career_impact', 'negative_perception', 
'bad_response_observed', 'less_likely_to_reveal', 'mental_health_diagnosis', 'diagnosed_condition', 
'sought_treatment', 'treated_interference', 'untreated_interference', 'age', 'gender', 
'country', 'state', 'work_position', 'remote_work']

# %%
# Changes 'sought_treatment' column values to Yes & No
df['sought_treatment'] = df['sought_treatment'].replace({0: 'No', 1: 'Yes'})

# %%
# Changes 'mental_health_coverage' column values to Yes & No
df['mental_health_coverage'] = df['mental_health_coverage'].replace({0: 'No', 1: 'Yes'})

# %%
df['tech_company'] = df['tech_company'].replace({0: 'No', 1: 'Yes'})

# %%
df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'Anxiety Disorder' if isinstance(x, str) and 'anxiety' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'Mood Disorder' if isinstance(x, str) and 'mood' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'Personality Disorder' if isinstance(x, str) and 'personality' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'ADHD' if isinstance(x, str) and 'attention deficit' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'PTSD' if isinstance(x, str) and 'post-traumatic' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'Substance Use Disorder' if isinstance(x, str) and 'substance use disorder' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'Psychotic Disorder' if isinstance(x, str) and 'psychotic disorder' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'Autism Spectrum Disorder' if isinstance(x, str) and 'autism' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'Autism Spectrum Disorder' if isinstance(x, str) and 'asperger' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'ADD' if isinstance(x, str) and 'add' in x.lower() else x)

df['diagnosed_condition'] = df['diagnosed_condition'].apply(lambda x: 'Eating Disorder' if isinstance(x, str) and 'eating' in x.lower() else x)

# %%
# Changes values to Male
to_replace_to_male = ["male", "M", "m", "man", "Male.", "Male (Cis)", "Cis male", "Man", "Sex is male", "cis male", "Dude", 
              "I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? ", 
              "M|", "Male/genderqueer", "male ", "cis male", "Male ", "Male (cis)", "mail", "cis man", "Cis Male", "cisdude", "MALE", "Malr"]

df['gender'] = df['gender'].replace(to_replace_to_male, 'Male')

# %%
# Changes values to Female
to_replace_to_female = ["female", "I identify as female.", "female ", "Female assigned at birth ", "F", "Woman", "f", "Cis female", "Female or Multi-Gender Femme", 
                       "Female ", "woman", "female/woman", "Cisgender Female", "genderqueer woman", "Female (props for making this a freeform field, though)", 
                       " Female", "female-bodied; no feelings about gender", "Cis female", "Genderfluid (born female)", "Cis female ", "Cis-woman", "fem"]

df['gender'] = df['gender'].replace(to_replace_to_female, 'Female')

# %%
# Changes values to Transgender
to_replace_to_transgender = ['Bigender', 'Transitioned, M2F', 'Other/Transfeminine', 'male 9:1 female, roughly', 'mtf', 
                            'Male (trans, FtM)', 'Transgender woman']

df['gender'] = df['gender'].replace(to_replace_to_transgender, 'Transgender')

# %%
# Changes values to Other
to_replace_to_other = ['non-binary', 'fm', 'Androgynous', 'Other',
 'nb masculine', 'none of your business', 'genderqueer', 'Human',
'Genderfluid', 'Enby', 'Queer', 'Agender', 'Fluid', 'Nonbinary', 'human',
 'Unicorn', 'Genderqueer', 'Genderflux demi-girl', 'AFAB',]

df['gender'] = df['gender'].replace(to_replace_to_other, "Other")

# %%
unique_values = df['remote_work'].unique()
print(unique_values)
# Out:
# ['Sometimes' 'Never' 'Always']

# %%
df.head()
# Out:
#   self_employed company_size tech_company tech_role mental_health_discussed  \
# 0            No       26-100          Yes       NaN                      No
# 1            No         6-25          Yes       NaN                     Yes
# 2            No         6-25          Yes       NaN                      No
# 3           Yes          NaN          NaN       NaN                 Unknown
# 4            No         6-25           No       Yes                      No
#
#   mental_health_resources          leave_request_ease negative_consequences  \
# 0                      No                   Very easy                    No
# 1                     Yes               Somewhat easy                    No
# 2                      No  Neither easy nor difficult                 Maybe
# 3                     NaN                         NaN                   NaN
# 4                      No  Neither easy nor difficult                   Yes
#
# ...
